# %% [markdown]
# # Legend Delta
#
# [![DBR](https://img.shields.io/badge/DBR-10.4 LTS-red?logo=databricks)](.)
# [![FINOS - Incubating](https://cdn.jsdelivr.net/gh/finos/contrib-toolbox@master/images/badge-incubating.svg)](https://finosfoundation.atlassian.net/wiki/display/FINOS/Incubating)
#
# *In addition to the JDBC connectivity enabled to Databricks from the [legend-engine](https://github.com/finos/legend-engine/tree/master/docs/databricks) itself,
# this project helps organizations define data models that can be converted into efficient data pipelines, ensuring data being queried
# is of high quality and availability. Raw data can be ingested as stream or batch and processed in line with the business semantics
# defined from the Legend interface. Domain specific language defined in Legend Studio can be interpreted as a series of Spark SQL operations,
# helping analysts create [Delta Lake](https://delta.io/) tables that not only guarantees schema definition but also complies
# with expectations, derivations and constraints defined by business analysts.*
#
# ___
#
#
# <img src='https://github.com/finos-labs/legend-delta/raw/main/images/legend-delta-workflow.png' width=30%>
#
# ___
#
# <antoine.amend@databricks.com>

# %% [markdown]
# ## Legend model
# Legend project can be loaded from classpath or directory as follows

# %%
# %scala
import org.finos.legend.spark.LegendClasspathLoader
val legend = LegendClasspathLoader.loadResources()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">import org.finos.legend.spark.LegendClasspathLoader
# legend: org.finos.legend.spark.Legend = org.finos.legend.spark.Legend@3eeb067
# </div>

# %% [markdown]
# All legend entities available will be retrieved and can be listed as follows

# %%
# %scala
val entities = legend.getEntityNames
display(entities.toSeq.toDF("pure"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pure</th></tr></thead><tbody><tr><td>databricks::mapping::developer_delta</td></tr><tr><td>databricks::entity::person</td></tr><tr><td>databricks::entity::sme</td></tr><tr><td>databricks::mapping::employee_developer</td></tr><tr><td>databricks::entity::employee</td></tr><tr><td>databricks::entity::developer</td></tr><tr><td>databricks::table::employee</td></tr><tr><td>databricks::mapping::employee_delta</td></tr><tr><td>databricks::table::developer</td></tr></tbody></table></div>

# %% [markdown]
# ## Legend schema
# We can create the spark schema for any Legend entity of type `Class`.
# This process will recursively loop through each of its underlying fields, enums and possibly nested properties and supertypes.

# %%
# %scala
val schema = legend.getSchema("databricks::entity::employee")
display(schema.fields.map(s => s.toDDL).toSeq.toDF("field"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>field</th></tr></thead><tbody><tr><td>firstName STRING NOT NULL COMMENT 'Person first name'</td></tr><tr><td>lastName STRING NOT NULL COMMENT 'Person last name'</td></tr><tr><td>birthDate DATE NOT NULL COMMENT 'Person birth date'</td></tr><tr><td>gender STRING COMMENT 'Person gender'</td></tr><tr><td>id INT NOT NULL COMMENT 'Unique identifier of a databricks employee'</td></tr><tr><td>sme STRING COMMENT 'Programming skill that person truly masters'</td></tr><tr><td>joinedDate DATE NOT NULL COMMENT 'When did that person join Databricks'</td></tr><tr><td>highFives INT COMMENT 'How many high fives did that person get'</td></tr></tbody></table></div>

# %% [markdown]
# ## Legend expectations
# Given the `multiplicity` properties, we can
# detect if a field is optional or not or list has the right number of elements. Given an `enumeration`,
# we check for value consistency. These will be considered **technical expectations** and converted into SQL constraints.

# %%
# %scala
val expectations = legend.getExpectations("databricks::entity::employee")
display(expectations.toSeq.toDF("name", "expectation"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>expectation</th></tr></thead><tbody><tr><td>[birthDate] is mandatory</td><td>birthDate IS NOT NULL</td></tr><tr><td>[sme] not allowed value</td><td>sme IS NULL OR sme IN ('Scala', 'Python', 'C', 'Java', 'R', 'SQL')</td></tr><tr><td>[id] is mandatory</td><td>id IS NOT NULL</td></tr><tr><td>[joinedDate] is mandatory</td><td>joinedDate IS NOT NULL</td></tr><tr><td>[firstName] is mandatory</td><td>firstName IS NOT NULL</td></tr><tr><td>[lastName] is mandatory</td><td>lastName IS NOT NULL</td></tr></tbody></table></div>

# %% [markdown]
# In addition to the rules derived from the schema itself, we also support the conversion of **business expectations**
# from the PURE language to SQL expressions. We generate a legend
# execution plan against a Databricks runtime, hence operating against relational legend `mapping` rather
# than pure entities of type `class`.

# %%
# %scala
val expectations = legend.getExpectations("databricks::mapping::employee_delta")
display(expectations.toSeq.toDF("name", "expectation"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>expectation</th></tr></thead><tbody><tr><td>[birthDate] is mandatory</td><td>birth_date IS NOT NULL</td></tr><tr><td>[sme] not allowed value</td><td>(sme IS NULL OR sme IN ('Scala', 'Python', 'C', 'Java', 'R', 'SQL'))</td></tr><tr><td>[id] is mandatory</td><td>id IS NOT NULL</td></tr><tr><td>[joinedDate] is mandatory</td><td>joined_date IS NOT NULL</td></tr><tr><td>[firstName] is mandatory</td><td>first_name IS NOT NULL</td></tr><tr><td>[high five] should be positive</td><td>(high_fives IS NOT NULL AND high_fives > 0)</td></tr><tr><td>[age] should be > 21</td><td>year(joined_date) - year(birth_date) > 21</td></tr><tr><td>[lastName] is mandatory</td><td>last_name IS NOT NULL</td></tr></tbody></table></div>

# %% [markdown]
# ## Legend transformations
# In addition to business expectations, we transform raw entities into their
# desired states and target tables. Note that relational transformations on legend only support direct mapping
# (no PURE operations or derived properties) and therefore easily enforced through `.withColumnRenamed` syntax.

# %%
# %scala
val transformations = legend.getTransformations("databricks::mapping::employee_delta")
display(transformations.toSeq.toDF("column", "columnRenamed"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>column</th><th>columnRenamed</th></tr></thead><tbody><tr><td>highFives</td><td>high_fives</td></tr><tr><td>joinedDate</td><td>joined_date</td></tr><tr><td>lastName</td><td>last_name</td></tr><tr><td>firstName</td><td>first_name</td></tr><tr><td>birthDate</td><td>birth_date</td></tr><tr><td>id</td><td>id</td></tr><tr><td>sme</td><td>sme</td></tr><tr><td>gender</td><td>gender</td></tr></tbody></table></div>

# %% [markdown]
# ## Legend tables
# In order to query our validated entity from legend interface, we can easily create the target state table. This table contains a placeholder for our invalidated constraints (below field `legend`).

# %%
# %scala
val tableName = legend.createTable("databricks::mapping::employee_delta")
display(sql(s"DESCRIBE EXTENDED $tableName"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>first_name</td><td>string</td><td>Person first name</td></tr><tr><td>last_name</td><td>string</td><td>Person last name</td></tr><tr><td>birth_date</td><td>date</td><td>Person birth date</td></tr><tr><td>gender</td><td>string</td><td>Person gender</td></tr><tr><td>id</td><td>int</td><td>Unique identifier of a databricks employee</td></tr><tr><td>sme</td><td>string</td><td>Programming skill that person truly masters</td></tr><tr><td>joined_date</td><td>date</td><td>When did that person join Databricks</td></tr><tr><td>high_fives</td><td>int</td><td>How many high fives did that person get</td></tr><tr><td>legend</td><td>array<string></td><td>LEGEND VALIDATION FIELD</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Partitioning</td><td></td><td></td></tr><tr><td>Not partitioned</td><td></td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Name</td><td>spark_catalog.legend.employee</td><td></td></tr><tr><td>Comment</td><td><Auto Generated> by Legend-Delta from PURE entity [databricks::entity::employee]</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></tbody></table></div>

# %% [markdown]
# # Example
# In this scenario, we read raw JSON files that we schematize, transform, validate and persist to a delta table. The resulting table will contain records that are both syntactically and semantically correct.

# %%
# %sh
head /dbfs/FileStore/antoine.amend@databricks.com/legend/employee.json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#34;birthDate&#34;:&#34;1989-02-19&#34;,&#34;firstName&#34;:&#34;Levey&#34;,&#34;gender&#34;:&#34;M&#34;,&#34;highFives&#34;:282,&#34;joinedDate&#34;:&#34;2015-12-05&#34;,&#34;lastName&#34;:&#34;Storck&#34;,&#34;role&#34;:&#34;SA&#34;,&#34;sme&#34;:&#34;C&#34;}
# {&#34;birthDate&#34;:&#34;1987-08-14&#34;,&#34;firstName&#34;:&#34;Maria&#34;,&#34;gender&#34;:&#34;M&#34;,&#34;highFives&#34;:299,&#34;id&#34;:2,&#34;joinedDate&#34;:&#34;2017-03-03&#34;,&#34;lastName&#34;:&#34;O&#39;Gorman&#34;,&#34;role&#34;:&#34;SA&#34;,&#34;sme&#34;:&#34;Python&#34;}
# {&#34;birthDate&#34;:&#34;1970-10-04&#34;,&#34;firstName&#34;:&#34;Evvy&#34;,&#34;gender&#34;:&#34;M&#34;,&#34;highFives&#34;:182,&#34;id&#34;:3,&#34;joinedDate&#34;:&#34;2020-11-02&#34;,&#34;lastName&#34;:&#34;Lepoidevin&#34;,&#34;role&#34;:&#34;GTM&#34;,&#34;sme&#34;:&#34;C&#34;}
# {&#34;birthDate&#34;:&#34;1973-11-26&#34;,&#34;firstName&#34;:&#34;Georges&#34;,&#34;gender&#34;:&#34;F&#34;,&#34;highFives&#34;:229,&#34;id&#34;:4,&#34;joinedDate&#34;:&#34;2020-09-14&#34;,&#34;lastName&#34;:&#34;Jotcham&#34;,&#34;role&#34;:&#34;GTM&#34;,&#34;sme&#34;:&#34;Scala&#34;}
# {&#34;birthDate&#34;:&#34;1987-03-11&#34;,&#34;firstName&#34;:&#34;Doroteya&#34;,&#34;gender&#34;:&#34;N&#34;,&#34;highFives&#34;:78,&#34;id&#34;:5,&#34;joinedDate&#34;:&#34;2019-02-11&#34;,&#34;lastName&#34;:&#34;Wadhams&#34;,&#34;role&#34;:&#34;ENG&#34;,&#34;sme&#34;:&#34;Scala&#34;}
# {&#34;birthDate&#34;:&#34;1988-08-01&#34;,&#34;firstName&#34;:&#34;Mia&#34;,&#34;gender&#34;:&#34;F&#34;,&#34;highFives&#34;:146,&#34;id&#34;:6,&#34;joinedDate&#34;:&#34;2017-04-13&#34;,&#34;lastName&#34;:&#34;Millgate&#34;,&#34;role&#34;:&#34;ENG&#34;,&#34;sme&#34;:&#34;Python&#34;}
# {&#34;birthDate&#34;:&#34;1979-07-15&#34;,&#34;firstName&#34;:&#34;Celene&#34;,&#34;gender&#34;:&#34;N&#34;,&#34;highFives&#34;:69,&#34;id&#34;:7,&#34;joinedDate&#34;:&#34;2021-06-03&#34;,&#34;lastName&#34;:&#34;Calverley&#34;,&#34;role&#34;:&#34;ENG&#34;,&#34;sme&#34;:&#34;Python&#34;}
# {&#34;birthDate&#34;:&#34;1980-05-18&#34;,&#34;firstName&#34;:&#34;Richie&#34;,&#34;gender&#34;:&#34;F&#34;,&#34;highFives&#34;:167,&#34;id&#34;:8,&#34;joinedDate&#34;:&#34;2014-08-23&#34;,&#34;lastName&#34;:&#34;Di Matteo&#34;,&#34;role&#34;:&#34;SA&#34;,&#34;sme&#34;:&#34;Python&#34;}
# {&#34;birthDate&#34;:&#34;1987-01-10&#34;,&#34;firstName&#34;:&#34;Ignaz&#34;,&#34;gender&#34;:&#34;F&#34;,&#34;highFives&#34;:199,&#34;joinedDate&#34;:&#34;2014-02-01&#34;,&#34;lastName&#34;:&#34;Kurth&#34;,&#34;role&#34;:&#34;RSA&#34;,&#34;sme&#34;:&#34;Python&#34;}
# {&#34;birthDate&#34;:&#34;1998-02-08&#34;,&#34;firstName&#34;:&#34;Anthia&#34;,&#34;gender&#34;:&#34;F&#34;,&#34;highFives&#34;:277,&#34;id&#34;:10,&#34;joinedDate&#34;:&#34;2015-01-14&#34;,&#34;lastName&#34;:&#34;Duck&#34;,&#34;role&#34;:&#34;RSA&#34;,&#34;sme&#34;:&#34;Python&#34;}
# </div>

# %%
# %scala
import org.finos.legend.spark._

val df = spark
  .read
  .format("json")
  .legendSchema("databricks::entity::employee")
  .load("/FileStore/antoine.amend@databricks.com/legend")

display(df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>firstName</th><th>lastName</th><th>birthDate</th><th>gender</th><th>id</th><th>sme</th><th>joinedDate</th><th>highFives</th></tr></thead><tbody><tr><td>Levey</td><td>Storck</td><td>1989-02-19</td><td>M</td><td>null</td><td>C</td><td>2015-12-05</td><td>282</td></tr><tr><td>Maria</td><td>O'Gorman</td><td>1987-08-14</td><td>M</td><td>2</td><td>Python</td><td>2017-03-03</td><td>299</td></tr><tr><td>Evvy</td><td>Lepoidevin</td><td>1970-10-04</td><td>M</td><td>3</td><td>C</td><td>2020-11-02</td><td>182</td></tr><tr><td>Georges</td><td>Jotcham</td><td>1973-11-26</td><td>F</td><td>4</td><td>Scala</td><td>2020-09-14</td><td>229</td></tr><tr><td>Doroteya</td><td>Wadhams</td><td>1987-03-11</td><td>N</td><td>5</td><td>Scala</td><td>2019-02-11</td><td>78</td></tr><tr><td>Mia</td><td>Millgate</td><td>1988-08-01</td><td>F</td><td>6</td><td>Python</td><td>2017-04-13</td><td>146</td></tr><tr><td>Celene</td><td>Calverley</td><td>1979-07-15</td><td>N</td><td>7</td><td>Python</td><td>2021-06-03</td><td>69</td></tr><tr><td>Richie</td><td>Di Matteo</td><td>1980-05-18</td><td>F</td><td>8</td><td>Python</td><td>2014-08-23</td><td>167</td></tr><tr><td>Ignaz</td><td>Kurth</td><td>1987-01-10</td><td>F</td><td>null</td><td>Python</td><td>2014-02-01</td><td>199</td></tr><tr><td>Anthia</td><td>Duck</td><td>1998-02-08</td><td>F</td><td>10</td><td>Python</td><td>2015-01-14</td><td>277</td></tr></tbody></table></div>

# %%
# %scala
val transformations = legend.getTransformations("databricks::mapping::employee_delta")
val transformedDf = df.legendTransform(transformations)
display(transformedDf.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_name</th><th>last_name</th><th>birth_date</th><th>gender</th><th>id</th><th>sme</th><th>joined_date</th><th>high_fives</th></tr></thead><tbody><tr><td>Levey</td><td>Storck</td><td>1989-02-19</td><td>M</td><td>null</td><td>C</td><td>2015-12-05</td><td>282</td></tr><tr><td>Maria</td><td>O'Gorman</td><td>1987-08-14</td><td>M</td><td>2</td><td>Python</td><td>2017-03-03</td><td>299</td></tr><tr><td>Evvy</td><td>Lepoidevin</td><td>1970-10-04</td><td>M</td><td>3</td><td>C</td><td>2020-11-02</td><td>182</td></tr><tr><td>Georges</td><td>Jotcham</td><td>1973-11-26</td><td>F</td><td>4</td><td>Scala</td><td>2020-09-14</td><td>229</td></tr><tr><td>Doroteya</td><td>Wadhams</td><td>1987-03-11</td><td>N</td><td>5</td><td>Scala</td><td>2019-02-11</td><td>78</td></tr><tr><td>Mia</td><td>Millgate</td><td>1988-08-01</td><td>F</td><td>6</td><td>Python</td><td>2017-04-13</td><td>146</td></tr><tr><td>Celene</td><td>Calverley</td><td>1979-07-15</td><td>N</td><td>7</td><td>Python</td><td>2021-06-03</td><td>69</td></tr><tr><td>Richie</td><td>Di Matteo</td><td>1980-05-18</td><td>F</td><td>8</td><td>Python</td><td>2014-08-23</td><td>167</td></tr><tr><td>Ignaz</td><td>Kurth</td><td>1987-01-10</td><td>F</td><td>null</td><td>Python</td><td>2014-02-01</td><td>199</td></tr><tr><td>Anthia</td><td>Duck</td><td>1998-02-08</td><td>F</td><td>10</td><td>Python</td><td>2015-01-14</td><td>277</td></tr></tbody></table></div>

# %%
# %scala
val expectations = legend.getExpectations("databricks::mapping::employee_delta")
val validatedDf = transformedDf.legendValidate(expectations)
display(validatedDf.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_name</th><th>last_name</th><th>birth_date</th><th>gender</th><th>id</th><th>sme</th><th>joined_date</th><th>high_fives</th><th>legend</th></tr></thead><tbody><tr><td>Levey</td><td>Storck</td><td>1989-02-19</td><td>M</td><td>null</td><td>C</td><td>2015-12-05</td><td>282</td><td>List([id] is mandatory)</td></tr><tr><td>Maria</td><td>O'Gorman</td><td>1987-08-14</td><td>M</td><td>2</td><td>Python</td><td>2017-03-03</td><td>299</td><td>List()</td></tr><tr><td>Evvy</td><td>Lepoidevin</td><td>1970-10-04</td><td>M</td><td>3</td><td>C</td><td>2020-11-02</td><td>182</td><td>List()</td></tr><tr><td>Georges</td><td>Jotcham</td><td>1973-11-26</td><td>F</td><td>4</td><td>Scala</td><td>2020-09-14</td><td>229</td><td>List()</td></tr><tr><td>Doroteya</td><td>Wadhams</td><td>1987-03-11</td><td>N</td><td>5</td><td>Scala</td><td>2019-02-11</td><td>78</td><td>List()</td></tr><tr><td>Mia</td><td>Millgate</td><td>1988-08-01</td><td>F</td><td>6</td><td>Python</td><td>2017-04-13</td><td>146</td><td>List()</td></tr><tr><td>Celene</td><td>Calverley</td><td>1979-07-15</td><td>N</td><td>7</td><td>Python</td><td>2021-06-03</td><td>69</td><td>List()</td></tr><tr><td>Richie</td><td>Di Matteo</td><td>1980-05-18</td><td>F</td><td>8</td><td>Python</td><td>2014-08-23</td><td>167</td><td>List()</td></tr><tr><td>Ignaz</td><td>Kurth</td><td>1987-01-10</td><td>F</td><td>null</td><td>Python</td><td>2014-02-01</td><td>199</td><td>List([id] is mandatory)</td></tr><tr><td>Anthia</td><td>Duck</td><td>1998-02-08</td><td>F</td><td>10</td><td>Python</td><td>2015-01-14</td><td>277</td><td>List([age] should be > 21)</td></tr></tbody></table></div>

# %%
# %scala
val tableName = legend.getTable("databricks::mapping::employee_delta")
validatedDf.write.format("delta").mode("append").saveAsTable(tableName)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">tableName: String = legend.employee
# </div>

# %%
# %scala
import org.apache.spark.sql.functions._
display(spark.read.table(tableName).limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_name</th><th>last_name</th><th>birth_date</th><th>gender</th><th>id</th><th>sme</th><th>joined_date</th><th>high_fives</th><th>legend</th></tr></thead><tbody><tr><td>Levey</td><td>Storck</td><td>1989-02-19</td><td>M</td><td>null</td><td>C</td><td>2015-12-05</td><td>282</td><td>List([id] is mandatory)</td></tr><tr><td>Maria</td><td>O'Gorman</td><td>1987-08-14</td><td>M</td><td>2</td><td>Python</td><td>2017-03-03</td><td>299</td><td>List()</td></tr><tr><td>Evvy</td><td>Lepoidevin</td><td>1970-10-04</td><td>M</td><td>3</td><td>C</td><td>2020-11-02</td><td>182</td><td>List()</td></tr><tr><td>Georges</td><td>Jotcham</td><td>1973-11-26</td><td>F</td><td>4</td><td>Scala</td><td>2020-09-14</td><td>229</td><td>List()</td></tr><tr><td>Doroteya</td><td>Wadhams</td><td>1987-03-11</td><td>N</td><td>5</td><td>Scala</td><td>2019-02-11</td><td>78</td><td>List()</td></tr><tr><td>Mia</td><td>Millgate</td><td>1988-08-01</td><td>F</td><td>6</td><td>Python</td><td>2017-04-13</td><td>146</td><td>List()</td></tr><tr><td>Celene</td><td>Calverley</td><td>1979-07-15</td><td>N</td><td>7</td><td>Python</td><td>2021-06-03</td><td>69</td><td>List()</td></tr><tr><td>Richie</td><td>Di Matteo</td><td>1980-05-18</td><td>F</td><td>8</td><td>Python</td><td>2014-08-23</td><td>167</td><td>List()</td></tr><tr><td>Ignaz</td><td>Kurth</td><td>1987-01-10</td><td>F</td><td>null</td><td>Python</td><td>2014-02-01</td><td>199</td><td>List([id] is mandatory)</td></tr><tr><td>Anthia</td><td>Duck</td><td>1998-02-08</td><td>F</td><td>10</td><td>Python</td><td>2015-01-14</td><td>277</td><td>List([age] should be > 21)</td></tr></tbody></table></div>

# %% [markdown]
# ## Continuous monitoring
# With new rules available from the legend studio, we can easily validate an entire legend table resulting in a new audited delta version

# %%
# %scala
val mappingName = "databricks::mapping::employee_delta"
val tableName = legend.getTable(mappingName)
val expectations = legend.getExpectations(mappingName)
legend.validateTable(mappingName)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">mappingName: String = databricks::mapping::employee_delta
# tableName: String = legend.employee
# expectations: Map[String,String] = Map([birthDate] is mandatory -&gt; birth_date IS NOT NULL, [sme] not allowed value -&gt; (sme IS NULL OR sme IN ('Scala', 'Python', 'C', 'Java', 'R', 'SQL')), [id] is mandatory -&gt; id IS NOT NULL, [joinedDate] is mandatory -&gt; joined_date IS NOT NULL, [firstName] is mandatory -&gt; first_name IS NOT NULL, [high five] should be positive -&gt; (high_fives IS NOT NULL AND high_fives &gt; 0), [age] should be &gt; 21 -&gt; year(joined_date) - year(birth_date) &gt; 21, [lastName] is mandatory -&gt; last_name IS NOT NULL)
# res16: io.delta.tables.DeltaTable = io.delta.tables.DeltaTable@39194e8b
# </div>

# %%
# %scala
display(sql(s"DESCRIBE HISTORY $tableName"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>2</td><td>2022-04-11T04:38:44.893+0000</td><td>999271697022884</td><td>antoine.amend@databricks.com</td><td>UPDATE</td><td>Map()</td><td>null</td><td>List(3591277798165548)</td><td>0410-051949-9j5ul4vr</td><td>1</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 1, numCopiedRows -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 1759, scanTimeMs -> 251, numAddedFiles -> 1, numUpdatedRows -> 1000, rewriteTimeMs -> 1501)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>1</td><td>2022-04-11T04:37:16.143+0000</td><td>999271697022884</td><td>antoine.amend@databricks.com</td><td>WRITE</td><td>Map(mode -> Append, partitionBy -> [])</td><td>null</td><td>List(3591277798165548)</td><td>0410-051949-9j5ul4vr</td><td>0</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1000, numOutputBytes -> 33930)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>0</td><td>2022-04-11T04:36:34.988+0000</td><td>999271697022884</td><td>antoine.amend@databricks.com</td><td>CREATE TABLE</td><td>Map(isManaged -> true, description -> <Auto Generated> by Legend-Delta from PURE entity [databricks::entity::employee], partitionBy -> [], properties -> {})</td><td>null</td><td>List(3591277798165548)</td><td>0410-051949-9j5ul4vr</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr></tbody></table></div>

# %%
# %scala
import org.apache.spark.sql.functions._

display(
  spark
    .read
    .table(tableName)
    .withColumn("constraint", explode(col("legend")))
    .groupBy("constraint")
    .count()
    .withColumnRenamed("count", "violations")
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>constraint</th><th>violations</th></tr></thead><tbody><tr><td>[id] is mandatory</td><td>2</td></tr><tr><td>[age] should be > 21</td><td>105</td></tr><tr><td>[sme] not allowed value</td><td>134</td></tr></tbody></table></div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
