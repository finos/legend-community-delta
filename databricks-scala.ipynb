# %%
# %sql
DROP DATABASE IF EXISTS legend CASCADE;
CREATE DATABASE legend;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## Legend model
# We can load a Legend data model from classpath or directory as follows

# %%
# %scala
import org.finos.legend.spark.LegendClasspathLoader
val legend = LegendClasspathLoader.loadResources()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">import org.finos.legend.spark.LegendClasspathLoader
# legend: org.finos.legend.spark.Legend = org.finos.legend.spark.Legend@5fc16956
# </div>

# %% [markdown]
# ## Legend entities
# All available entities will be retrieved from our legend data model

# %%
# %scala
val entities = legend.getEntityNames
display(entities.toSeq.toDF("pure"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pure</th></tr></thead><tbody><tr><td>databricks::runtime::employee</td></tr><tr><td>databricks::entity::person</td></tr><tr><td>databricks::entity::sme</td></tr><tr><td>databricks::service::skills</td></tr><tr><td>databricks::lakehouse::employee</td></tr><tr><td>databricks::entity::employee</td></tr><tr><td>databricks::table::employee</td></tr><tr><td>databricks::service::employee</td></tr><tr><td>databricks::mapping::employee_delta</td></tr></tbody></table></div>

# %% [markdown]
# ## Legend schema
# We can create the spark schema for any Legend entity. This process will recursively loop through each underlying fields, enums, nested properties and supertypes.

# %%
# %scala
val schema = legend.getSchema("databricks::entity::employee")
display(schema.fields.map(s => s.toDDL).toSeq.toDF("field"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>field</th></tr></thead><tbody><tr><td>firstName STRING NOT NULL COMMENT 'Person first name'</td></tr><tr><td>lastName STRING NOT NULL COMMENT 'Person last name'</td></tr><tr><td>birthDate DATE NOT NULL COMMENT 'Person birth date'</td></tr><tr><td>gender STRING COMMENT 'Person gender'</td></tr><tr><td>id INT COMMENT 'Unique ID of a databricks employee'</td></tr><tr><td>sme STRING COMMENT 'Programming skill that person truly masters'</td></tr><tr><td>joinedDate DATE NOT NULL COMMENT 'When did that person join Databricks'</td></tr><tr><td>highFives INT COMMENT 'How many high fives did that person get'</td></tr></tbody></table></div>

# %% [markdown]
# ## Legend transformations
# We can transform raw entities into their desired target tables. Note that relational transformations only support direct mapping and therefore easily enforced through `.withColumnRenamed` syntax.

# %%
# %scala
val transformations = legend.getTransformations("databricks::mapping::employee_delta")
display(transformations.toSeq.toDF("column", "columnRenamed"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>column</th><th>columnRenamed</th></tr></thead><tbody><tr><td>highFives</td><td>high_fives</td></tr><tr><td>joinedDate</td><td>joined_date</td></tr><tr><td>lastName</td><td>last_name</td></tr><tr><td>firstName</td><td>first_name</td></tr><tr><td>birthDate</td><td>birth_date</td></tr><tr><td>id</td><td>id</td></tr><tr><td>sme</td><td>sme</td></tr><tr><td>gender</td><td>gender</td></tr></tbody></table></div>

# %% [markdown]
# ## Legend expectations
# Given the `multiplicity` properties, we can
# detect if a field is optional or not or list has the right number of elements. Given an `enumeration`,
# we check for value consistency. These will be considered **technical expectations** and converted into SQL constraints. In addition, we also support the conversion of **business expectations**
# from the PURE language to SQL expressions. We generate a legend
# execution plan against a Databricks runtime

# %%
# %scala
val expectations = legend.getExpectations("databricks::mapping::employee_delta")
display(expectations.toSeq.toDF("name", "expectation"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>expectation</th></tr></thead><tbody><tr><td>[birthDate] is mandatory</td><td>birth_date IS NOT NULL</td></tr><tr><td>[sme] not allowed value</td><td>(sme IS NULL OR sme IN ('Scala', 'Python', 'Java', 'R', 'SQL'))</td></tr><tr><td>[joinedDate] is mandatory</td><td>joined_date IS NOT NULL</td></tr><tr><td>[firstName] is mandatory</td><td>first_name IS NOT NULL</td></tr><tr><td>[high five] should be positive</td><td>(high_fives IS NOT NULL AND high_fives > 0)</td></tr><tr><td>[lastName] is mandatory</td><td>last_name IS NOT NULL</td></tr><tr><td>[hiringAge] should be > 18</td><td>year(joined_date) - year(birth_date) > 18</td></tr></tbody></table></div>

# %% [markdown]
# ## Legend derivations
# We can convert Legend derived properties as SQL expressions. In the example model, the field `age` is not physically stored but can be computed at runtime.

# %%
# %scala
val derivations = legend.getDerivations("databricks::mapping::employee_delta")
display(derivations.toSeq.toDF("column", "expression"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>column</th><th>expression</th></tr></thead><tbody><tr><td>hiringAge</td><td>year(joined_date) - year(birth_date) AS `hiringAge`</td></tr><tr><td>age</td><td>year(current_date) - year(birth_date) AS `age`</td></tr></tbody></table></div>

# %% [markdown]
# ## Legend tables
# In order to query our validated entity from legend interface, we can easily create the target state table.

# %%
# %scala
val tableName = legend.createTable("databricks::mapping::employee_delta")
display(sql(s"DESCRIBE EXTENDED $tableName"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>first_name</td><td>string</td><td>Person first name</td></tr><tr><td>last_name</td><td>string</td><td>Person last name</td></tr><tr><td>birth_date</td><td>date</td><td>Person birth date</td></tr><tr><td>gender</td><td>string</td><td>Person gender</td></tr><tr><td>id</td><td>int</td><td>Unique ID of a databricks employee</td></tr><tr><td>sme</td><td>string</td><td>Programming skill that person truly masters</td></tr><tr><td>joined_date</td><td>date</td><td>When did that person join Databricks</td></tr><tr><td>high_fives</td><td>int</td><td>How many high fives did that person get</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Partitioning</td><td></td><td></td></tr><tr><td>Not partitioned</td><td></td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>spark_catalog</td><td></td></tr><tr><td>Database</td><td>legend</td><td></td></tr><tr><td>Table</td><td>employee</td><td></td></tr><tr><td>Comment</td><td><Auto Generated> by Legend-Delta from PURE entity [databricks::entity::employee]</td><td></td></tr><tr><td>Location</td><td>dbfs:/user/hive/warehouse/legend.db/employee</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Table Properties</td><td>[delta.minReaderVersion=1,delta.minWriterVersion=2]</td><td></td></tr></tbody></table></div>

# %% [markdown]
# # Example - write
# In this scenario, we read raw JSON files that we schematize, transform and persist to our target state delta table.

# %%
# %sh
head /dbfs/FileStore/antoine.amend@databricks.com/legend/employee.json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&#34;birthDate&#34;:&#34;1989-02-19&#34;,&#34;firstName&#34;:&#34;Levey&#34;,&#34;gender&#34;:&#34;M&#34;,&#34;highFives&#34;:282,&#34;joinedDate&#34;:&#34;2015-12-05&#34;,&#34;lastName&#34;:&#34;Storck&#34;,&#34;role&#34;:&#34;SA&#34;,&#34;sme&#34;:&#34;C&#34;}
# {&#34;birthDate&#34;:&#34;1987-08-14&#34;,&#34;firstName&#34;:&#34;Maria&#34;,&#34;gender&#34;:&#34;M&#34;,&#34;highFives&#34;:299,&#34;id&#34;:2,&#34;joinedDate&#34;:&#34;2017-03-03&#34;,&#34;lastName&#34;:&#34;O&#39;Gorman&#34;,&#34;role&#34;:&#34;SA&#34;,&#34;sme&#34;:&#34;Python&#34;}
# {&#34;birthDate&#34;:&#34;1998-02-08&#34;,&#34;firstName&#34;:&#34;Anthia&#34;,&#34;gender&#34;:&#34;F&#34;,&#34;highFives&#34;:277,&#34;id&#34;:10,&#34;joinedDate&#34;:&#34;2015-01-14&#34;,&#34;lastName&#34;:&#34;Duck&#34;,&#34;role&#34;:&#34;RSA&#34;,&#34;sme&#34;:&#34;Python&#34;}
# </div>

# %%
# %scala
val schema = legend.getSchema("databricks::entity::employee")
val schemaDf = spark.read.format("json").schema(schema).load("/FileStore/antoine.amend@databricks.com/legend")
display(schemaDf.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>firstName</th><th>lastName</th><th>birthDate</th><th>gender</th><th>id</th><th>sme</th><th>joinedDate</th><th>highFives</th></tr></thead><tbody><tr><td>Levey</td><td>Storck</td><td>1989-02-19</td><td>M</td><td>null</td><td>C</td><td>2015-12-05</td><td>282</td></tr><tr><td>Maria</td><td>O'Gorman</td><td>1987-08-14</td><td>M</td><td>2</td><td>Python</td><td>2017-03-03</td><td>299</td></tr><tr><td>Evvy</td><td>Lepoidevin</td><td>1970-10-04</td><td>M</td><td>3</td><td>C</td><td>2020-11-02</td><td>182</td></tr><tr><td>Georges</td><td>Jotcham</td><td>1973-11-26</td><td>F</td><td>4</td><td>Scala</td><td>2020-09-14</td><td>229</td></tr><tr><td>Doroteya</td><td>Wadhams</td><td>1987-03-11</td><td>N</td><td>5</td><td>Scala</td><td>2019-02-11</td><td>78</td></tr><tr><td>Mia</td><td>Millgate</td><td>1988-08-01</td><td>F</td><td>6</td><td>Python</td><td>2017-04-13</td><td>146</td></tr><tr><td>Celene</td><td>Calverley</td><td>1979-07-15</td><td>N</td><td>7</td><td>Python</td><td>2021-06-03</td><td>69</td></tr><tr><td>Richie</td><td>Di Matteo</td><td>1980-05-18</td><td>F</td><td>8</td><td>Python</td><td>2014-08-23</td><td>167</td></tr><tr><td>Ignaz</td><td>Kurth</td><td>1987-01-10</td><td>F</td><td>null</td><td>Python</td><td>2014-02-01</td><td>199</td></tr><tr><td>Anthia</td><td>Duck</td><td>1998-02-08</td><td>F</td><td>10</td><td>Python</td><td>2015-01-14</td><td>277</td></tr></tbody></table></div>

# %%
# %scala
import org.finos.legend.spark._
val transformations = legend.getTransformations("databricks::mapping::employee_delta")
val transformedDf = schemaDf.legendTransform(transformations)
display(transformedDf.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_name</th><th>last_name</th><th>birth_date</th><th>gender</th><th>id</th><th>sme</th><th>joined_date</th><th>high_fives</th></tr></thead><tbody><tr><td>Levey</td><td>Storck</td><td>1989-02-19</td><td>M</td><td>null</td><td>C</td><td>2015-12-05</td><td>282</td></tr><tr><td>Maria</td><td>O'Gorman</td><td>1987-08-14</td><td>M</td><td>2</td><td>Python</td><td>2017-03-03</td><td>299</td></tr><tr><td>Evvy</td><td>Lepoidevin</td><td>1970-10-04</td><td>M</td><td>3</td><td>C</td><td>2020-11-02</td><td>182</td></tr><tr><td>Georges</td><td>Jotcham</td><td>1973-11-26</td><td>F</td><td>4</td><td>Scala</td><td>2020-09-14</td><td>229</td></tr><tr><td>Doroteya</td><td>Wadhams</td><td>1987-03-11</td><td>N</td><td>5</td><td>Scala</td><td>2019-02-11</td><td>78</td></tr><tr><td>Mia</td><td>Millgate</td><td>1988-08-01</td><td>F</td><td>6</td><td>Python</td><td>2017-04-13</td><td>146</td></tr><tr><td>Celene</td><td>Calverley</td><td>1979-07-15</td><td>N</td><td>7</td><td>Python</td><td>2021-06-03</td><td>69</td></tr><tr><td>Richie</td><td>Di Matteo</td><td>1980-05-18</td><td>F</td><td>8</td><td>Python</td><td>2014-08-23</td><td>167</td></tr><tr><td>Ignaz</td><td>Kurth</td><td>1987-01-10</td><td>F</td><td>null</td><td>Python</td><td>2014-02-01</td><td>199</td></tr><tr><td>Anthia</td><td>Duck</td><td>1998-02-08</td><td>F</td><td>10</td><td>Python</td><td>2015-01-14</td><td>277</td></tr></tbody></table></div>

# %%
# %scala
val tableName = legend.getTable("databricks::mapping::employee_delta")
transformedDf.write.format("delta").mode("append").saveAsTable(tableName)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">tableName: String = legend.employee
# </div>

# %% [markdown]
# # Example - drift
# Given our delta backend, we may decide to allow / decline data drift. A new schema update would result in seamless execution of pipeline with zero code overhead

# %%
# %scala
// Let's create an additional field
import org.apache.spark.sql.functions._
val updated_schemaDf = spark.read.format("json").schema(schema).load("/FileStore/antoine.amend@databricks.com/legend").withColumn("isMvp", lit(true))
val updated_transformedDf = updated_schemaDf.legendTransform(transformations)
display(updated_transformedDf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_name</th><th>last_name</th><th>birth_date</th><th>gender</th><th>id</th><th>sme</th><th>joined_date</th><th>high_fives</th><th>isMvp</th></tr></thead><tbody><tr><td>Levey</td><td>Storck</td><td>1989-02-19</td><td>M</td><td>null</td><td>C</td><td>2015-12-05</td><td>282</td><td>true</td></tr><tr><td>Maria</td><td>O'Gorman</td><td>1987-08-14</td><td>M</td><td>2</td><td>Python</td><td>2017-03-03</td><td>299</td><td>true</td></tr><tr><td>Evvy</td><td>Lepoidevin</td><td>1970-10-04</td><td>M</td><td>3</td><td>C</td><td>2020-11-02</td><td>182</td><td>true</td></tr><tr><td>Georges</td><td>Jotcham</td><td>1973-11-26</td><td>F</td><td>4</td><td>Scala</td><td>2020-09-14</td><td>229</td><td>true</td></tr><tr><td>Doroteya</td><td>Wadhams</td><td>1987-03-11</td><td>N</td><td>5</td><td>Scala</td><td>2019-02-11</td><td>78</td><td>true</td></tr><tr><td>Mia</td><td>Millgate</td><td>1988-08-01</td><td>F</td><td>6</td><td>Python</td><td>2017-04-13</td><td>146</td><td>true</td></tr><tr><td>Celene</td><td>Calverley</td><td>1979-07-15</td><td>N</td><td>7</td><td>Python</td><td>2021-06-03</td><td>69</td><td>true</td></tr><tr><td>Richie</td><td>Di Matteo</td><td>1980-05-18</td><td>F</td><td>8</td><td>Python</td><td>2014-08-23</td><td>167</td><td>true</td></tr><tr><td>Ignaz</td><td>Kurth</td><td>1987-01-10</td><td>F</td><td>null</td><td>Python</td><td>2014-02-01</td><td>199</td><td>true</td></tr><tr><td>Anthia</td><td>Duck
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">A schema mismatch detected when writing to the Delta table (Table ID: ee04410d-53db-4f37-a977-8f0960ed5e78).
# To enable schema migration using DataFrameWriter or DataStreamWriter, please set:
# '.option(&quot;mergeSchema&quot;, &quot;true&quot;)'.
# For other operations, set the session configuration
# spark.databricks.delta.schema.autoMerge.enabled to &quot;true&quot;. See the documentation
# specific to the operation for details.
#
# Table schema:
# root
# -- first_name: string (nullable = true)
# -- last_name: string (nullable = true)
# -- birth_date: date (nullable = true)
# -- gender: string (nullable = true)
# -- id: integer (nullable = true)
# -- sme: string (nullable = true)
# -- joined_date: date (nullable = true)
# -- high_fives: integer (nullable = true)
#
#
# Data schema:
# root
# -- first_name: string (nullable = true)
# -- last_name: string (nullable = true)
# -- birth_date: date (nullable = true)
# -- gender: string (nullable = true)
# -- id: integer (nullable = true)
# -- sme: string (nullable = true)
# -- joined_date: date (nullable = true)
# -- high_fives: integer (nullable = true)
# -- isMvp: boolean (nullable = true)
#
#
# </div>

# %%
# %scala
updated_transformedDf.write.format("delta").mode("append").option("mergeSchema", "true").saveAsTable(tableName)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %scala
val versionDF = sql(s"DESCRIBE HISTORY ${tableName}")
val versionLatest = versionDF.select(max("version").alias("version")).collect().head.getAs[Long]("version")
display(versionDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>2</td><td>2022-07-16T05:11:42.800+0000</td><td>999271697022884</td><td>antoine.amend@databricks.com</td><td>WRITE</td><td>Map(mode -> Append, partitionBy -> [])</td><td>null</td><td>List(3591277798165548)</td><td>0410-051949-9j5ul4vr</td><td>1</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1000, numOutputBytes -> 33274)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>1</td><td>2022-07-16T05:10:32.686+0000</td><td>999271697022884</td><td>antoine.amend@databricks.com</td><td>WRITE</td><td>Map(mode -> Append, partitionBy -> [])</td><td>null</td><td>List(3591277798165548)</td><td>0410-051949-9j5ul4vr</td><td>0</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1000, numOutputBytes -> 33051)</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr><tr><td>0</td><td>2022-07-16T05:09:59.186+0000</td><td>999271697022884</td><td>antoine.amend@databricks.com</td><td>CREATE TABLE</td><td>Map(isManaged -> true, description -> <Auto Generated> by Legend-Delta from PURE entity [databricks::entity::employee], partitionBy -> [], properties -> {})</td><td>null</td><td>List(3591277798165548)</td><td>0410-051949-9j5ul4vr</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/10.4.x-scala2.12</td></tr></tbody></table></div>

# %%
# %scala
display(sql(s"SELECT * FROM $tableName VERSION AS OF ${versionLatest}"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_name</th><th>last_name</th><th>birth_date</th><th>gender</th><th>id</th><th>sme</th><th>joined_date</th><th>high_fives</th><th>isMvp</th></tr></thead><tbody><tr><td>Levey</td><td>Storck</td><td>1989-02-19</td><td>M</td><td>null</td><td>C</td><td>2015-12-05</td><td>282</td><td>true</td></tr><tr><td>Maria</td><td>O'Gorman</td><td>1987-08-14</td><td>M</td><td>2</td><td>Python</td><td>2017-03-03</td><td>299</td><td>true</td></tr><tr><td>Evvy</td><td>Lepoidevin</td><td>1970-10-04</td><td>M</td><td>3</td><td>C</td><td>2020-11-02</td><td>182</td><td>true</td></tr><tr><td>Georges</td><td>Jotcham</td><td>1973-11-26</td><td>F</td><td>4</td><td>Scala</td><td>2020-09-14</td><td>229</td><td>true</td></tr><tr><td>Doroteya</td><td>Wadhams</td><td>1987-03-11</td><td>N</td><td>5</td><td>Scala</td><td>2019-02-11</td><td>78</td><td>true</td></tr><tr><td>Mia</td><td>Millgate</td><td>1988-08
><td>true</td><td>[hiringAge] should be > 18</td></tr><tr><td>Ross</td><td>Bernhard</td><td>1988-12-25</td><td>F</td><td>17</td><td>C</td><td>2017-03-13</td><td>243</td><td>true</td><td>[sme] not allowed value</td></tr><tr><td>Eachelle</td><td>Martynka</td><td>1979-03-21</td><td>M</td><td>24</td><td>SAS</td><td>2021-01-27</td><td>156</td><td>true</td><td>[sme] not allowed value</td></tr><tr><td>Yanaton</td><td>Schultz</td><td>1999-04-16</td><td>F</td><td>27</td><td>Python</td><td>2016-07-30</td><td>261</td><td>true</td><td>[hiringAge] should be > 18</td></tr><tr><td>Ianthe</td><td>Sherwin</td><td>1998-12-17</td><td>M</td><td>30</td><td>Java</td><td>2014-07-21</td><td>26</td><td>true</td><td>[hiringAge] should be > 18</td></tr><tr><td>Bailie</td><td>Caltun</td><td>1979-11-19</td><td>F</td><td>31</td><td>C</td><td>2015-07-04</td><td>204</td><td>true</td><td>[sme] not allowed value</td></tr><tr><td>Rooney</td><td>Hacksby</td><td>1974-04-20</td><td>F</td><td>38</td><td>C</td><td>2015-04-12</td><td>134</td><td>true</td><td>[sme] not allowed value</td></tr><tr><td>Cecilius</td><td>Askham</td><td>1984-04-01</td><td>N</td><td>40</td><td>C</td><td>2014-11-20</td><td>36</td><td>true</td><td>[sme] not allowed value</td></tr></tbody></table></div>

# %% [markdown]
# # Example - read
# From delta, we read objects that we transform back as a pure entity with derived properties and violated constraints. New derivations could be added from legend studio and seamlessly computed here without the need for engineering team to code. The generated dataframe would comply with business expectations and data quality, as defined from the legend studio.

# %%
# %scala
val legendDf = legend.query("databricks::mapping::employee_delta")
display(legendDf.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>highFives</th><th>joinedDate</th><th>lastName</th><th>firstName</th><th>birthDate</th><th>id</th><th>sme</th><th>gender</th><th>hiringAge</th><th>age</th></tr></thead><tbody><tr><td>282</td><td>2015-12-05</td><td>Storck</td><td>Levey</td><td>1989-02-19</td><td>null</td><td>C</td><td>M</td><td>26</td><td>33</td></tr><tr><td>299</td><td>2017-03-03</td><td>O'Gorman</td><td>Maria</td><td>1987-08-14</td><td>2</td><td>Python</td><td>M</td><td>30</td><td>35</td></tr><tr><td>182</td><td>2020-11-02</td><td>Lepoidevin</td><td>Evvy</td><td>1970-10-04</td><td>3</td><td>C</td><td>M</td><td>50</td><td>52</td></tr><tr><td>229</td><td>2020-09-14</td><td>Jotcham</td><td>Georges</td><td>1973-11-26</td><td>4</td><td>Scala</td><td>F</td><td>47</td><td>49</td></tr><tr><td>78</td><td>2019-02-11</td><td>Wadhams</td><td>Doroteya</td><td>1987-03-11</td><td>5</td><td>Scala</td><td>N</td><td>32</td><td>35</td></tr><tr><td>146</td><td>2017-04-13</td><td>Millgate</td><td>Mia</td><td>1988-08-01</td><td>6</td><td>Python</td><td>F</td><td>29</td><td>34</td></tr><tr><td>69</td><td>2021-06-03</td><td>Calverley</td><td>Celene</td><td>1979-07-15</td><td>7</td><td>Python</td><td>N</td><td>42</td><td>43</td></tr><tr><td>167</td><td>2014-08-23</td><td>Di Matteo</td><td>Richie</td><td>1980-05-18</td><td>8</td><td>Python</td><td>F</td><td>34</td><td>42</td></tr><tr><td>199</td><td>2014-02-01</td><td>Kurth</td><td>Ignaz</td><td>1987-01-10</td><td>null</td><td>Python</td><td>F</td><td>27</td><td>35</td></tr><tr><td>277</td><td>2015-01-14</td><td>Duck</td><td>Anthia</td><td>1998-02-08</td><td>10</td><td>Python</td><td>F</td><td>17</td><td>24</td></tr></tbody></table></div>

# %% [markdown]
# Given the following service defined on legend studio, we generate the corresponding spark execution plan and return a dataframe with all requested attributes and calculations
#
# ```
# |databricks::entity::employee.all()->filter(
#   x|$x.firstName->startsWith('G')
# )->project(
#   [
#     x|$x.firstName,
#     x|$x.lastName,
#     x|$x.highFives,
#     x|$x.age,
#     x|$x.sme
#   ],
#   [
#     'FirstName',
#     'LastName',
#     'HighFives',
#     'Age',
#     'Sme'
#   ]
# )->sort(
#   [
#     desc('HighFives')
#   ]
# )->take(10)
# ```

# %%
# %scala
val legendDf = legend.query("databricks::service::employee")
display(legendDf.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>FirstName</th><th>LastName</th><th>HighFives</th><th>Age</th><th>Sme</th></tr></thead><tbody><tr><td>Giustina</td><td>Pullen</td><td>300</td><td>45</td><td>Python</td></tr><tr><td>Giustina</td><td>Pullen</td><td>300</td><td>45</td><td>Python</td></tr><tr><td>Garth</td><td>Pucker</td><td>294</td><td>33</td><td>Python</td></tr><tr><td>Garth</td><td>Pucker</td><td>294</td><td>33</td><td>Python</td></tr><tr><td>Garv</td><td>Rulf</td><td>287</td><td>43</td><td>C</td></tr><tr><td>Garv</td><td>Rulf</td><td>287</td><td>43</td><td>C</td></tr><tr><td>Gonzales</td><td>Mewton</td><td>284</td><td>47</td><td>Python</td></tr><tr><td>Gonzales</td><td>Mewton</td><td>284</td><td>47</td><td>Python</td></tr><tr><td>Gib</td><td>Thorius</td><td>282</td><td>51</td><td>SAS</td></tr><tr><td>Gib</td><td>Thorius</td><td>282</td><td>51</td><td>SAS</td></tr></tbody></table></div>

# %% [markdown]
# The same works against aggregated functions like `groupBy`
#
# ```
# |databricks::entity::employee.all()->filter(
#   x|!($x.gender->isEmpty())
# )->groupBy(
#   [
#     x|$x.gender
#   ],
#   [
#     agg(
#       x|$x.highFives,
#       x|$x->average()
#     ),
#     agg(
#       x|$x.id,
#       x|$x->count()
#     )
#   ],
#   [
#     'Gender',
#     'HighFives',
#     'Employees'
#   ]
# )->sort(
#   [
#     desc('HighFives')
#   ]
# )->take(10)
# ```

# %%
# %scala
val legendDf = legend.query("databricks::service::skills")
display(legendDf.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Gender</th><th>HighFives</th><th>Employees</th></tr></thead><tbody><tr><td>N</td><td>167.09091</td><td>88</td></tr><tr><td>M</td><td>152.09620</td><td>788</td></tr><tr><td>F</td><td>150.23941</td><td>1084</td></tr></tbody></table></div>
